# %%
import pandas as pd
import json
import polars as pl
import pathlib
from typing import Type
import datetime

ENCODING = 'utf-8'
INPUT_PATH = pathlib.Path().absolute().parent / "data" / "predict-energy-behavior-of-prosumers" / "client.csv"
COUNTY_MAP_PATH: pathlib.Path = pathlib.Path().absolute().parent / "data" / "predict-energy-behavior-of-prosumers" / "county_id_to_name_map.json"
BASE_PATH: pathlib.Path = pathlib.Path().absolute().parent / "data" / "raw" / "clients"

product_type_map: dict[int, str] = {0: "Combined", 1: "Fixed", 2: "General service", 3: "Spot"}

# %%
def preprocess_product_type(data: pl.DataFrame) -> pl.DataFrame:
    """Preprocesses the product type column in the given DataFrame.

    Args:
        data (pd.DataFrame): The DataFrame containing the product type column.

    Returns:
        pd.DataFrame: The DataFrame with the product type column preprocessed.

    Examples:
        >>> data = pd.DataFrame({"product_type": ["A", "B", "C"]})
        >>> preprocess_product_type(data)
           product_type
        0             A
        1             B
        2             C
    """
    # data["product_type"] = data["product_type"].apply(lambda x: product_type_map.get(x, x))
    return data.with_columns([pl.col("product_type").replace(product_type_map, default="General service")])


def preprocess_county(data: pl.DataFrame) -> pl.DataFrame:
    """Preprocesses the county column in the given DataFrame.

    Args:
        data (pd.DataFrame): The DataFrame containing the county column.

    Returns:
        pd.DataFrame: The DataFrame with the county column preprocessed.

    Examples:
        >>> data = pd.DataFrame({"county": [1, 2, 3]})
        >>> preprocess_county(data)
           county
        0  County1
        1  County2
        2  County3
    """
    with COUNTY_MAP_PATH.open("r") as f:
        county_id_to_name_map: dict[int, str] = json.load(f)

    return data.with_columns([pl.col("county").replace(county_id_to_name_map, default="Unknown")])


def preprocess_date(data: pl.DataFrame) -> pl.DataFrame:
    """Preprocesses the date column in the given DataFrame by converting it to datetime format.

    Args:
        data (pd.DataFrame): The DataFrame containing the date column.

    Returns:
        pd.DataFrame: The DataFrame with the date column preprocessed.

    Examples:
        >>> data = pd.DataFrame({"date": ["2022-01-01", "2022-01-02", "2022-01-03"]})
        >>> preprocess_date(data)
               date
        0 2022-01-01
        1 2022-01-02
        2 2022-01-03
    """
    # data["date"] = pd.to_datetime(data["date"])
    return data.with_columns([pl.col("date").str.to_date("%Y-%m-%d")])


def preprocess_is_business(data: pl.DataFrame) -> pl.DataFrame:
    """Preprocesses the is_business column in the given DataFrame by replacing 0 with False and 1 with True.

    Args:
        data (pd.DataFrame): The DataFrame containing the is_business column.

    Returns:
        pd.DataFrame: The DataFrame with the is_business column preprocessed.

    Examples:
        >>> data = pd.DataFrame({"is_business": [0, 1, 0]})
        >>> preprocess_is_business(data)
           is_business
        0        False
        1         True
        2        False
    """
    # data["is_business"] = data["is_business"].replace({0: False, 1: True})
    return data.with_columns([pl.col("is_business").cast(pl.Boolean)])


def preprocess_clients_columns(data: pl.DataFrame) -> pd.DataFrame:
    """Preprocesses multiple columns in the given DataFrame.

    This function applies a series of preprocessing steps to the product_type, county, date, and is_business columns in
        the DataFrame.

    Args:
        data (pd.DataFrame): The DataFrame to be preprocessed.

    Returns:
        pd.DataFrame: The preprocessed DataFrame.

    Examples:
        >>> data = pd.DataFrame({"product_type": ["A", "B", "C"], "county": [1, 2, 3],
            "date": ["2022-01-01", "2022-01-02", "2022-01-03"], "is_business": [0, 1, 0]})
        >>> preprocess_clients_columns(data)
           product_type   county       date  is_business
        0             A  County1 2022-01-01        False
        1             B  County2 2022-01-02         True
        2             C  County3 2022-01-03        False
    """
    data = preprocess_product_type(data)
    data = preprocess_county(data)
    return preprocess_is_business(data)


def set_column_types(data: pl.DataFrame) -> pl.DataFrame:
    """Sets the column types of the given DataFrame.

    This function iterates over each column in the DataFrame and sets the column types based on their current dtype.
        Columns with dtype 'object' are converted to 'string[pyarrow]', columns with dtype 'int' are converted to
        'int32', and columns with dtype 'float' are converted to 'float32'.

    Args:
        data (pd.DataFrame): The DataFrame to set the column types.

    Returns:
        pd.DataFrame: The DataFrame with the updated column types.
    """
    column_mapping: dict[Type[pl.Int64 | pl.Float64], Type[pl.Int32 | pl.Float32]] = {
        pl.Int64: pl.Int32,
        pl.Float64: pl.Float32,
    }
    return data.with_columns(
        [
            pl.col(column).cast(column_mapping.get(col_dtype, col_dtype))
            for column, col_dtype in zip(data.columns, data.dtypes)
        ]
    )


def fetch_clients_at_day(day: datetime.date) -> pl.DataFrame:
    """Fetches client data at a specific day from a Kafka consumer.

    This function creates a Kafka consumer and fetches client data from the specified day. The fetched data is returned
        as a pandas DataFrame.

    Args:
        day (datetime.date): The specific day to fetch client data.

    Returns:
        pd.DataFrame: The DataFrame containing the fetched client data.
    """
    clients: pd.DataFrame = pd.read_csv(INPUT_PATH)

    clients_row: list[dict] = []
    for _, row in clients.iterrows():
        clients_row.append(row.to_dict())

    data = pl.from_dicts(clients_row)
    return preprocess_date(data).filter(pl.col("date") == day)

def create_base_output_path(date: datetime.date) -> pathlib.Path:
    """Creates the base output path for client data.

    This function takes a date and constructs the base output path for storing client data. The output path is a
        pathlib.Path object.

    Args:
        date (datetime.date): The date used to construct the base output path.

    Returns:
        pathlib.Path: The base output path for client data.
    """
    year, month, day = date.year, date.month, date.day
    return BASE_PATH / str(year) / str(month) / str(day) / "clients.parquet"


def save_clients_to_datalake(data: pd.DataFrame, output_path: pathlib.Path) -> bool:
    """Saves client data to the datalake.

    This function takes a DataFrame of client data and a specific day, and saves the data to the datalake. The data is
        saved as a parquet file at the corresponding output path based on the given day.

    Args:
        data (pd.DataFrame): The DataFrame of client data to be saved.
        day (datetime.date): The specific day associated with the client data.

    Returns:
        bool: True if the data is successfully saved, False otherwise.
    """
    # print(f"output path: {output_path}")
    try:
        output_path.parent.mkdir(parents=True, exist_ok=True)
        data.write_parquet(output_path)
        return True
    except Exception as e:
        print(e)
        return False

# %%
# Prenditi tutti i dati di ieri da kafka
start_date: datetime.date = datetime.date(year=2021, month=9, day=1)
end_date: datetime.date = datetime.date(year=2023, month=5, day=29)
days_to_process: datetime.timedelta = end_date - start_date

processed_dates = []
unprocessed_dates = []

for day_offset in range(days_to_process.days + 1):
    process_date: datetime.date = start_date + datetime.timedelta(days=day_offset)
    output_path: pathlib.Path = create_base_output_path(process_date)
    if output_path.exists():
        print(f"{process_date} already processed")
        continue

    print(f"Processing {process_date}")

    clients: pl.DataFrame = fetch_clients_at_day(day=process_date)

    clients = set_column_types(clients)

    clients = preprocess_clients_columns(clients)

    if data_saved := save_clients_to_datalake(clients, output_path):
        processed_dates.append(process_date)
    else:
        unprocessed_dates.append(process_date)

unprocessed_dates
# Out:
# 2021-09-01 already processed
# 2021-09-02 already processed
# 2021-09-03 already processed
# 2021-09-04 already processed
# 2021-09-05 already processed
# 2021-09-06 already processed
# 2021-09-07 already processed
# 2021-09-08 already processed
# 2021-09-09 already processed
# 2021-09-10 already processed
# 2021-09-11 already processed
# 2021-09-12 already processed
# 2021-09-13 already processed
# 2021-09-14 already processed
# 2021-09-15 already processed
# 2021-09-16 already processed
# 2021-09-17 already processed
# 2021-09-18 already processed
# 2021-09-19 already processed
# 2021-09-20 already processed
# 2021-09-21 already processed
# 2021-09-22 already processed
# 2021-09-23 already processed
# 2021-09-24 already processed
# 2021-09-25 already processed
# 2021-09-26 already processed
# 2021-09-27 already processed
# 2021-09-28 already processed
# 2021-09-29 already processed
# 2021-09-30 already processed
# 2021-10-01 already processed
# 2021-10-02 already processed
# 2021-10-03 already processed
# 2021-10-04 already processed
# 2021-10-05 already processed
# 2021-10-06 already processed
# 2021-10-07 already processed
# 2021-10-08 already processed
# 2021-10-09 already processed
# 2021-10-10 already processed
# 2021-10-11 already processed
# 2021-10-12 already processed
# 2021-10-13 already processed
# 2021-10-14 already processed
# 2021-10-15 already processed
# 2021-10-16 already processed
# 2021-10-17 already processed
# 2021-10-18 already processed
# 2021-10-19 already processed
# 2021-10-20 already processed
# 2021-10-21 already processed
# 2021-10-22 already processed
# 2021-10-23 already processed
# 2021-10-24 already processed
# 2021-10-25 already processed
# 2021-10-26 already processed
# 2021-10-27 already processed
# 2021-10-28 already processed
# 2021-10-29 already processed
# 2021-10-30 already processed
# 2021-10-31 already processed
# 2021-11-01 already processed
# 2021-11-02 already processed
# 2021-11-03 already processed
# 2021-11-04 already processed
# 2021-11-05 already processed
# 2021-11-06 already processed
# 2021-11-07 already processed
# 2021-11-08 already processed
# 2021-11-09 already processed
# 2021-11-10 already processed
# 2021-11-11 already processed
# 2021-11-12 already processed
# 2021-11-13 already processed
# 2021-11-14 already processed
# 2021-11-15 already processed
# 2021-11-16 already processed
# 2021-11-17 already processed
# 2021-11-18 already processed
# 2021-11-19 already processed
# 2021-11-20 already processed
# 2021-11-21 already processed
# 2021-11-22 already processed
# 2021-11-23 already processed
# 2021-11-24 already processed
# 2021-11-25 already processed
# 2021-11-26 already processed
# 2021-11-27 already processed
# 2021-11-28 already processed
# 2021-11-29 already processed
# 2021-11-30 already processed
# 2021-12-01 already processed
# 2021-12-02 already processed
# 2021-12-03 already processed
# 2021-12-04 already processed
# 2021-12-05 already processed
# 2021-12-06 already processed
# 2021-12-07 already processed
# 2021-12-08 already processed
# 2021-12-09 already processed
# 2021-12-10 already processed
# 2021-12-11 already processed
# 2021-12-12 already processed
# 2021-12-13 already processed
# 2021-12-14 already processed
# 2021-12-15 already processed
# 2021-12-16 already processed
# 2021-12-17 already processed
# 2021-12-18 already processed
# 2021-12-19 already processed
# 2021-12-20 already processed
# 2021-12-21 already processed
# 2021-12-22 already processed
# 2021-12-23 already processed
# 2021-12-24 already processed
# 2021-12-25 already processed
# 2021-12-26 already processed
# 2021-12-27 already processed
# 2021-12-28 already processed
# 2021-12-29 already processed
# 2021-12-30 already processed
# 2021-12-31 already processed
# 2022-01-01 already processed
# 2022-01-02 already processed
# 2022-01-03 already processed
# 2022-01-04 already processed
# 2022-01-05 already processed
# 2022-01-06 already processed
# 2022-01-07 already processed
# 2022-01-08 already processed
# 2022-01-09 already processed
# 2022-01-10 already processed
# 2022-01-11 already processed
# 2022-01-12 already processed
# 2022-01-13 already processed
# 2022-01-14 already processed
# 2022-01-15 already processed
# 2022-01-16 already processed
# 2022-01-17 already processed
# 2022-01-18 already processed
# 2022-01-19 already processed
# 2022-01-20 already processed
# 2022-01-21 already processed
# 2022-01-22 already processed
# 2022-01-23 already processed
# 2022-01-24 already processed
# 2022-01-25 already processed
# 2022-01-26 already processed
# 2022-01-27 already processed
# 2022-01-28 already processed
# 2022-01-29 already processed
# 2022-01-30 already processed
# 2022-01-31 already processed
# 2022-02-01 already processed
# 2022-02-02 already processed
# 2022-02-03 already processed
# 2022-02-04 already processed
# 2022-02-05 already processed
# 2022-02-06 already processed
# 2022-02-07 already processed
# 2022-02-08 already processed
# 2022-02-09 already processed
# 2022-02-10 already processed
# 2022-02-11 already processed
# 2022-02-12 already processed
# 2022-02-13 already processed
# 2022-02-14 already processed
# 2022-02-15 already processed
# 2022-02-16 already processed
# 2022-02-17 already processed
# 2022-02-18 already processed
# 2022-02-19 already processed
# 2022-02-20 already processed
# 2022-02-21 already processed
# 2022-02-22 already processed
# 2022-02-23 already processed
# 2022-02-24 already processed
# 2022-02-25 already processed
# 2022-02-26 already processed
# 2022-02-27 already processed
# 2022-02-28 already processed
# 2022-03-01 already processed
# 2022-03-02 already processed
# 2022-03-03 already processed
# 2022-03-04 already processed
# 2022-03-05 already processed
# 2022-03-06 already processed
# 2022-03-07 already processed
# 2022-03-08 already processed
# 2022-03-09 already processed
# 2022-03-10 already processed
# 2022-03-11 already processed
# 2022-03-12 already processed
# 2022-03-13 already processed
# 2022-03-14 already processed
# 2022-03-15 already processed
# 2022-03-16 already processed
# 2022-03-17 already processed
# 2022-03-18 already processed
# 2022-03-19 already processed
# 2022-03-20 already processed
# 2022-03-21 already processed
# 2022-03-22 already processed
# 2022-03-23 already processed
# 2022-03-24 already processed
# 2022-03-25 already processed
# 2022-03-26 already processed
# 2022-03-27 already processed
# 2022-03-28 already processed
# 2022-03-29 already processed
# 2022-03-30 already processed
# 2022-03-31 already processed
# 2022-04-01 already processed
# 2022-04-02 already processed
# 2022-04-03 already processed
# 2022-04-04 already processed
# 2022-04-05 already processed
# 2022-04-06 already processed
# 2022-04-07 already processed
# 2022-04-08 already processed
# 2022-04-09 already processed
# 2022-04-10 already processed
# 2022-04-11 already processed
# 2022-04-12 already processed
# 2022-04-13 already processed
# 2022-04-14 already processed
# 2022-04-15 already processed
# 2022-04-16 already processed
# 2022-04-17 already processed
# 2022-04-18 already processed
# 2022-04-19 already processed
# 2022-04-20 already processed
# 2022-04-21 already processed
# 2022-04-22 already processed
# 2022-04-23 already processed
# 2022-04-24 already processed
# 2022-04-25 already processed
# 2022-04-26 already processed
# 2022-04-27 already processed
# 2022-04-28 already processed
# 2022-04-29 already processed
# 2022-04-30 already processed
# 2022-05-01 already processed
# 2022-05-02 already processed
# 2022-05-03 already processed
# 2022-05-04 already processed
# 2022-05-05 already processed
# 2022-05-06 already processed
# 2022-05-07 already processed
# 2022-05-08 already processed
# 2022-05-09 already processed
# 2022-05-10 already processed
# 2022-05-11 already processed
# 2022-05-12 already processed
# 2022-05-13 already processed
# 2022-05-14 already processed
# 2022-05-15 already processed
# 2022-05-16 already processed
# 2022-05-17 already processed
# 2022-05-18 already processed
# 2022-05-19 already processed
# 2022-05-20 already processed
# Processing 2022-05-21
# Processing 2022-05-22
# Processing 2022-05-23
# Processing 2022-05-24
# Processing 2022-05-25
# Processing 2022-05-26
# Processing 2022-05-27
# Processing 2022-05-28
# Processing 2022-05-29
# Processing 2022-05-30
# Processing 2022-05-31
# Processing 2022-06-01
# Processing 2022-06-02
# Processing 2022-06-03
# Processing 2022-06-04
# Processing 2022-06-05
# Processing 2022-06-06
# Processing 2022-06-07
# Processing 2022-06-08
# Processing 2022-06-09
# Processing 2022-06-10
# Processing 2022-06-11
# Processing 2022-06-12
# Processing 2022-06-13
# Processing 2022-06-14
# Processing 2022-06-15
# Processing 2022-06-16
# Processing 2022-06-17
# Processing 2022-06-18
# Processing 2022-06-19
# Processing 2022-06-20
# Processing 2022-06-21
# Processing 2022-06-22
# Processing 2022-06-23
# Processing 2022-06-24
# Processing 2022-06-25
# Processing 2022-06-26
# Processing 2022-06-27
# Processing 2022-06-28
# Processing 2022-06-29
# Processing 2022-06-30
# Processing 2022-07-01
# Processing 2022-07-02
# Processing 2022-07-03
# Processing 2022-07-04
# Processing 2022-07-05
# Processing 2022-07-06
# Processing 2022-07-07
# Processing 2022-07-08
# Processing 2022-07-09
# Processing 2022-07-10
# Processing 2022-07-11
# Processing 2022-07-12
# Processing 2022-07-13
# Processing 2022-07-14
# Processing 2022-07-15
# Processing 2022-07-16
# Processing 2022-07-17
# Processing 2022-07-18
# Processing 2022-07-19
# Processing 2022-07-20
# Processing 2022-07-21
# Processing 2022-07-22
# Processing 2022-07-23
# Processing 2022-07-24
# Processing 2022-07-25
# Processing 2022-07-26
# Processing 2022-07-27
# Processing 2022-07-28
# Processing 2022-07-29
# Processing 2022-07-30
# Processing 2022-07-31
# Processing 2022-08-01
# Processing 2022-08-02
# Processing 2022-08-03
# Processing 2022-08-04
# Processing 2022-08-05
# Processing 2022-08-06
# Processing 2022-08-07
# Processing 2022-08-08
# Processing 2022-08-09
# Processing 2022-08-10
# Processing 2022-08-11
# Processing 2022-08-12
# Processing 2022-08-13
# Processing 2022-08-14
# Processing 2022-08-15
# Processing 2022-08-16
# Processing 2022-08-17
# Processing 2022-08-18
# Processing 2022-08-19
# Processing 2022-08-20
# Processing 2022-08-21
# Processing 2022-08-22
# Processing 2022-08-23
# Processing 2022-08-24
# Processing 2022-08-25
# Processing 2022-08-26
# Processing 2022-08-27
# Processing 2022-08-28
# Processing 2022-08-29
# Processing 2022-08-30
# Processing 2022-08-31
# Processing 2022-09-01
# Processing 2022-09-02
# Processing 2022-09-03
# Processing 2022-09-04
# Processing 2022-09-05
# Processing 2022-09-06
# Processing 2022-09-07
# Processing 2022-09-08
# Processing 2022-09-09
# Processing 2022-09-10
# Processing 2022-09-11
# Processing 2022-09-12
# Processing 2022-09-13
# Processing 2022-09-14
# Processing 2022-09-15
# Processing 2022-09-16
# Processing 2022-09-17
# Processing 2022-09-18
# Processing 2022-09-19
# Processing 2022-09-20
# Processing 2022-09-21
# Processing 2022-09-22
# Processing 2022-09-23
# Processing 2022-09-24
# Processing 2022-09-25
# Processing 2022-09-26
# Processing 2022-09-27
# Processing 2022-09-28
# Processing 2022-09-29
# Processing 2022-09-30
# Processing 2022-10-01
# Processing 2022-10-02
# Processing 2022-10-03
# Processing 2022-10-04
# Processing 2022-10-05
# Processing 2022-10-06
# Processing 2022-10-07
# Processing 2022-10-08
# Processing 2022-10-09
# Processing 2022-10-10
# Processing 2022-10-11
# Processing 2022-10-12
# Processing 2022-10-13
# Processing 2022-10-14
# Processing 2022-10-15
# Processing 2022-10-16
# Processing 2022-10-17
# Processing 2022-10-18
# Processing 2022-10-19
# Processing 2022-10-20
# Processing 2022-10-21
# Processing 2022-10-22
# Processing 2022-10-23
# Processing 2022-10-24
# Processing 2022-10-25
# Processing 2022-10-26
# Processing 2022-10-27
# Processing 2022-10-28
# Processing 2022-10-29
# Processing 2022-10-30
# Processing 2022-10-31
# Processing 2022-11-01
# Processing 2022-11-02
# Processing 2022-11-03
# Processing 2022-11-04
# Processing 2022-11-05
# Processing 2022-11-06
# Processing 2022-11-07
# Processing 2022-11-08
# Processing 2022-11-09
# Processing 2022-11-10
# Processing 2022-11-11
# Processing 2022-11-12
# Processing 2022-11-13
# Processing 2022-11-14
# Processing 2022-11-15
# Processing 2022-11-16
# Processing 2022-11-17
# Processing 2022-11-18
# Processing 2022-11-19
# Processing 2022-11-20
# Processing 2022-11-21
# Processing 2022-11-22
# Processing 2022-11-23
# Processing 2022-11-24
# Processing 2022-11-25
# Processing 2022-11-26
# Processing 2022-11-27
# Processing 2022-11-28
# Processing 2022-11-29
# Processing 2022-11-30
# Processing 2022-12-01
# Processing 2022-12-02
# Processing 2022-12-03
# Processing 2022-12-04
# Processing 2022-12-05
# Processing 2022-12-06
# Processing 2022-12-07
# Processing 2022-12-08
# Processing 2022-12-09
# Processing 2022-12-10
# Processing 2022-12-11
# Processing 2022-12-12
# Processing 2022-12-13
# Processing 2022-12-14
# Processing 2022-12-15
# Processing 2022-12-16
# Processing 2022-12-17
# Processing 2022-12-18
# Processing 2022-12-19
# Processing 2022-12-20
# Processing 2022-12-21
# Processing 2022-12-22
# Processing 2022-12-23
# Processing 2022-12-24
# Processing 2022-12-25
# Processing 2022-12-26
# Processing 2022-12-27
# Processing 2022-12-28
# Processing 2022-12-29
# Processing 2022-12-30
# Processing 2022-12-31
# Processing 2023-01-01
# Processing 2023-01-02
# Processing 2023-01-03
# Processing 2023-01-04
# Processing 2023-01-05
# Processing 2023-01-06
# Processing 2023-01-07
# Processing 2023-01-08
# Processing 2023-01-09
# Processing 2023-01-10
# Processing 2023-01-11
# Processing 2023-01-12
# Processing 2023-01-13
# Processing 2023-01-14
# Processing 2023-01-15
# Processing 2023-01-16
# Processing 2023-01-17
# Processing 2023-01-18
# Processing 2023-01-19
# Processing 2023-01-20
# Processing 2023-01-21
# Processing 2023-01-22
# Processing 2023-01-23
# Processing 2023-01-24
# Processing 2023-01-25
# Processing 2023-01-26
# Processing 2023-01-27
# Processing 2023-01-28
# Processing 2023-01-29
# Processing 2023-01-30
# Processing 2023-01-31
# Processing 2023-02-01
# Processing 2023-02-02
# Processing 2023-02-03
# Processing 2023-02-04
# Processing 2023-02-05
# Processing 2023-02-06
# Processing 2023-02-07
# Processing 2023-02-08
# Processing 2023-02-09
# Processing 2023-02-10
# Processing 2023-02-11
# Processing 2023-02-12
# Processing 2023-02-13
# Processing 2023-02-14
# Processing 2023-02-15
# Processing 2023-02-16
# Processing 2023-02-17
# Processing 2023-02-18
# Processing 2023-02-19
# Processing 2023-02-20
# Processing 2023-02-21
# Processing 2023-02-22
# Processing 2023-02-23
# Processing 2023-02-24
# Processing 2023-02-25
# Processing 2023-02-26
# Processing 2023-02-27
# Processing 2023-02-28
# Processing 2023-03-01
# Processing 2023-03-02
# Processing 2023-03-03
# Processing 2023-03-04
# Processing 2023-03-05
# Processing 2023-03-06
# Processing 2023-03-07
# Processing 2023-03-08
# Processing 2023-03-09
# Processing 2023-03-10
# Processing 2023-03-11
# Processing 2023-03-12
# Processing 2023-03-13
# Processing 2023-03-14
# Processing 2023-03-15
# Processing 2023-03-16
# Processing 2023-03-17
# Processing 2023-03-18
# Processing 2023-03-19
# Processing 2023-03-20
# Processing 2023-03-21
# Processing 2023-03-22
# Processing 2023-03-23
# Processing 2023-03-24
# Processing 2023-03-25
# Processing 2023-03-26
# Processing 2023-03-27
# Processing 2023-03-28
# Processing 2023-03-29
# Processing 2023-03-30
# Processing 2023-03-31
# Processing 2023-04-01
# Processing 2023-04-02
# Processing 2023-04-03
# Processing 2023-04-04
# Processing 2023-04-05
# Processing 2023-04-06
# Processing 2023-04-07
# Processing 2023-04-08
# Processing 2023-04-09
# Processing 2023-04-10
# Processing 2023-04-11
# Processing 2023-04-12
# Processing 2023-04-13
# Processing 2023-04-14
# Processing 2023-04-15
# Processing 2023-04-16
# Processing 2023-04-17
# Processing 2023-04-18
# Processing 2023-04-19
# Processing 2023-04-20
# Processing 2023-04-21
# Processing 2023-04-22
# Processing 2023-04-23
# Processing 2023-04-24
# Processing 2023-04-25
# Processing 2023-04-26
# Processing 2023-04-27
# Processing 2023-04-28
# Processing 2023-04-29
# Processing 2023-04-30
# Processing 2023-05-01
# Processing 2023-05-02
# Processing 2023-05-03
# Processing 2023-05-04
# Processing 2023-05-05
# Processing 2023-05-06
# Processing 2023-05-07
# Processing 2023-05-08
# Processing 2023-05-09
# Processing 2023-05-10
# Processing 2023-05-11
# Processing 2023-05-12
# Processing 2023-05-13
# Processing 2023-05-14
# Processing 2023-05-15
# Processing 2023-05-16
# Processing 2023-05-17
# Processing 2023-05-18
# Processing 2023-05-19
# Processing 2023-05-20
# Processing 2023-05-21
# Processing 2023-05-22
# Processing 2023-05-23
# Processing 2023-05-24
# Processing 2023-05-25
# Processing 2023-05-26
# Processing 2023-05-27
# Processing 2023-05-28
# Processing 2023-05-29
# []
